# %% [markdown]
# <a href="https://colab.research.google.com/github/msaleem-aisci/Neural-Network-course/blob/main/test3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
